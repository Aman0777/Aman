# %% [markdown]
# <a href="https://colab.research.google.com/github/Aman0777/Aman/blob/master/ChatBot_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q anthropic
import os
from anthropic import Anthropic

client = Anthropic(
    api_key="sk-ant-api03-bs7opZrG0hFpN-UVh1Ip9w_xO9_jwcwa0CG201A3uOehGDaopT0XXIAApjrBjmEAfQV5UeRGNmXC1VlMLew-Qg-06-FtQXX"
)

messages = []
def getUserPrompt (prompt) :
    messages.append(
      {
          "role":"user",
          "content":prompt
      }
    )
    response = client.messages.create(
      model="claude-sonnet-4-5",
      max_tokens=1000,
      system="You are a helpful assistant chatbot. Give me short response always",
      messages=messages
    )
    messages.append(
      {
          "role":"assistant",
          "content":response.content[0].text
      }
    )
    return response


if __name__ == "__main__" :
  while True:
    prompt = input("Input : ")
    if(prompt == "exit" or prompt == "bye" or prompt == "quit") :
      break
    resp = getUserPrompt(prompt)
    print(resp.content[0].text)

  print("Thank You !!")
# Out:
# ...
# Input : Who is MS Dhoni
# MS Dhoni is a former Indian cricket captain and wicketkeeper-batsman, widely regarded as one of cricket's greatest captains. Key facts:
#
# - **Full name**: Mahendra Singh Dhoni
# - **Born**: July 7, 1981
# - **Known for**: Leading India to win the 2007 T20 World Cup, 2011 Cricket World Cup, and 2013 Champions Trophy
# - **Playing style**: Calm under pressure, powerful finisher, lightning-fast stumping
# - **Nickname**: "Captain Cool"
# - **IPL**: Captain of Chennai Super Kings (CSK)
# - **Retired**: From international cricket in August 2020
#
# He's considered one of India's most successful cricket captains ever.
# Input : Who is his Wife
# MS Dhoni's wife is **Sakshi Dhoni** (née Sakshi Singh Rawat).
#
# Key facts:
# - **Married**: July 4, 2010
# - **Background**: They knew each other from school days in Ranchi
# - **Profession**: She has worked as a hotel management professional
# - **Daughter**: They have a daughter named Ziva, born in 2015
#
# ...
